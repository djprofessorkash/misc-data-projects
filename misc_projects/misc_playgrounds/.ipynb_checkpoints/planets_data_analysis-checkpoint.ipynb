# %% [markdown]
# ## Dataset from the [NASA Exoplanet Archive](https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=planets).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
path_data = '../misc_datasets/planets.csv'
df_planets = pd.read_csv(path_data)
# df_planets

# %%
path_dict = '../misc_datasets/planets_data_dict.csv'
df_planets_data_dict = pd.read_csv(path_dict)
# df_planets_data_dict

# %%
planet_data_dict = dict()
data_list = df_planets_data_dict['# This file was produced by the NASA Exoplanet Archive  http://exoplanetarchive.ipac.caltech.edu']

for i in range(2, len(data_list)):
    data_list[i] = data_list[i].replace("# COLUMN ", "").split(":")
    planet_data_dict[data_list[i][0]] = data_list[i][1].strip()

# %%
df_planets_clean = df_planets.rename(columns = planet_data_dict).drop("rowid", 1)

# %%
# df_planets_clean

# %%
# df_planets_clean.describe()

# %%
df_planets_data_dict.values
# Out:
# array([['# Wed Jan 17 17:12:50 2018'],
#        ['#'],
#        [list(['pl_hostname', '    Host Name'])],
#        [list(['pl_letter', '      Planet Letter'])],
#        [list(['pl_discmethod', '  Discovery Method'])],
#        [list(['pl_pnum', '        Number of Planets in System'])],
#        [list(['pl_orbper', '      Orbital Period [days]'])],
#        [list(['pl_orbpererr1', '  Orbital Period Upper Unc. [days]'])],
#        [list(['pl_orbpererr2', '  Orbital Period Lower Unc. [days]'])],
#        [list(['pl_orbperlim', '   Orbital Period Limit Flag'])],
#        [list(['pl_orbsmax', '     Orbit Semi-Major Axis [AU]'])],
#        [list(['pl_orbsmaxerr1', ' Orbit Semi-Major Axis Upper Unc. [AU]'])],
#        [list(['pl_orbsmaxerr2', ' Orbit Semi-Major Axis Lower Unc. [AU]'])],
#        [list(['pl_orbsmaxlim', '  Orbit Semi-Major Axis Limit Flag'])],
#        [list(['pl_orbeccen', '    Eccentricity'])],
#        [list(['pl_orbeccenerr1', ' Eccentricity Upper Unc.'])],
#        [list(['pl_orbeccenerr2', ' Eccentricity Lower Unc.'])],
#        [list(['pl_orbeccenlim', ' Eccentricity Limit Flag'])],
#        [list(['pl_orbincl', '     Inclination [deg]'])],
#        [list(['pl_orbinclerr1', ' Inclination Upper Unc. [deg]'])],
#        [list(['pl_orbinclerr2', ' Inclination Lower Unc. [deg]'])],
#        [list(['pl_orbincllim', '  Inclination Limit Flag'])],
#        [list(['pl_bmassj', '      Planet Mass or M*sin(i)[Jupiter mass]'])],
#        [ list(['pl_bmassjerr1', '  Planet Mass or M*sin(i)Upper Unc. [Jupiter mass]'])],
#        [ list(['pl_bmassjerr2', '  Planet Mass or M*sin(i)Lower Unc. [Jupiter mass]'])],
#        [list(['pl_bmassjlim', '   Planet Mass or M*sin(i)Limit Flag'])],
#        [list(['pl_bmassprov', '   Planet Mass or M*sin(i) Provenance'])],
#        [list(['pl_radj', '        Planet Radius [Jupiter radii]'])],
#        [list(['pl_radjerr1', '    Planet Radius Upper Unc. [Jupiter radii]'])],
#        [list(['pl_radjerr2', '    Planet Radius Lower Unc. [Jupiter radii]'])],
#        [list(['pl_radjlim', '     Planet Radius Limit Flag'])],
#        [list(['pl_dens', '        Planet Density [g/cm**3]'])],
#        [list(['pl_denserr1', '    Planet Density Upper Unc. [g/cm**3]'])],
#        [list(['pl_denserr2', '    Planet Density Lower Unc. [g/cm**3]'])],
#        [list(['pl_denslim', '     Planet Density Limit Flag'])],
#        [list(['pl_ttvflag', '     TTV Flag'])],
#        [list(['pl_kepflag', '     Kepler Field Flag'])],
#        [list(['pl_k2flag', '      K2 Mission Flag'])],
#        [list(['pl_nnotes', '      Number of Notes'])],
#        [list(['ra_str', '         RA [sexagesimal]'])],
#        [list(['ra', '             RA [sexagesimal]'])],
#        [list(['dec_str', '        Dec [sexagesimal]'])],
#        [list(['dec', '            Dec [sexagesimal]'])],
#        [list(['st_dist', '        Distance [pc]'])],
#        [list(['st_disterr1', '    Distance Upper Unc. [pc]'])],
#        [list(['st_disterr2', '    Distance Lower Unc. [pc]'])],
#        [list(['st_distlim', '     Distance Limit Flag'])],
#        [list(['st_optmag', '      Optical Magnitude [mag]'])],
#        [list(['st_optmagerr', '   Optical Magnitude Unc. [mag]'])],
#        [list(['st_optmaglim', '   Optical Magnitude Limit Flag'])],
#        [list(['st_optmagblend', ' Optical Magnitude Blend Flag'])],
#        [list(['st_optband', '     Optical Magnitude Band'])],
#        [list(['gaia_gmag', '      G-band (Gaia) [mag]'])],
#        [list(['gaia_gmagerr', '   G-band (Gaia) Unc. [mag]'])],
#        [list(['gaia_gmaglim', '   G-band (Gaia) Limit Flag'])],
#        [list(['st_teff', '        Effective Temperature [K]'])],
#        [list(['st_tefferr1', '    Effective Temperature Upper Unc. [K]'])],
#        [list(['st_tefferr2', '    Effective Temperature Lower Unc. [K]'])],
#        [list(['st_tefflim', '     Effective Temperature Limit Flag'])],
#        [list(['st_teffblend', '   Effective Temperature Blend Flag'])],
#        [list(['st_mass', '        Stellar Mass [Solar mass]'])],
#        [list(['st_masserr1', '    Stellar Mass Upper Unc. [Solar mass]'])],
#        [list(['st_masserr2', '    Stellar Mass Lower Unc. [Solar mass]'])],
#        [list(['st_masslim', '     Stellar Mass Limit Flag'])],
#        [list(['st_massblend', '   Stellar Mass Blend Flag'])],
#        [list(['st_rad', '         Stellar Radius [Solar radii]'])],
#        [list(['st_raderr1', '     Stellar Radius Upper Unc. [Solar radii]'])],
#        [list(['st_raderr2', '     Stellar Radius Lower Unc. [Solar radii]'])],
#        [list(['st_radlim', '      Stellar Radius Limit Flag'])],
#        [list(['st_radblend', '    Stellar Radius Blend Flag'])],
#        [list(['rowupdate', '      Date of Last Update'])],
#        [list(['pl_name', '        Planet Name'])],
#        [list(['pl_tranflag', '    Planet Transit Flag'])],
#        [list(['pl_rvflag', '      Planet RV Flag'])],
#        [list(['pl_imgflag', '     Planet Imaging Flag'])],
#        [list(['pl_astflag', '     Planet Astrometry Flag'])],
#        [list(['pl_omflag', '      Planet Orbital Modulation Flag'])],
#        [list(['pl_cbflag', '      Planet Circumbinary Flag'])],
#        [list(['pl_angsep', '      Calculated Angular Separation [mas]'])],
#        [ list(['pl_angseperr1', '  Calculated Angular Separation Upper Unc. [mas]'])],
#        [ list(['pl_angseperr2', '  Calculated Angular Separation Lower Unc. [mas]'])],
#        [list(['pl_orbtper', '     Time of Periastron [days]'])],
#        [list(['pl_orbtpererr1', ' Time of Periastron Upper Unc. [days]'])],
#        [list(['pl_orbtpererr2', ' Time of Periastron Lower Unc. [days]'])],
#        [list(['pl_orbtperlim', '  Time of Periastron Limit Flag'])],
#        [list(['pl_orblper', '     Long. of Periastron [deg]'])],
#        [list(['pl_orblpererr1', ' Long. of Periastron Upper Unc. [deg]'])],
#        [list(['pl_orblpererr2', ' Long. of Periastron Lower Unc. [deg]'])],
#        [list(['pl_orblperlim', '  Long. of Periastron Limit Flag'])],
#        [list(['pl_rvamp', '       Radial Velocity Amplitude [m/s]'])],
#        [list(['pl_rvamperr1', '   Radial Velocity Amplitude Upper Unc. [m/s]'])],
#        [list(['pl_rvamperr2', '   Radial Velocity Amplitude Lower Unc. [m/s]'])],
#        [list(['pl_rvamplim', '    Radial Velocity Amplitude Limit Flag'])],
#        [list(['pl_eqt', '         Equilibrium Temperature [K]'])],
#        [list(['pl_eqterr1', '     Equilibrium Temperature Upper Unc. [K]'])],
#        [list(['pl_eqterr2', '     Equilibrium Temperature Lower Unc. [K]'])],
#        [list(['pl_eqtlim', '      Equilibrium Temperature Limit Flag'])],
#        [list(['pl_insol', '       Insolation Flux [Earth flux]'])],
#        [list(['pl_insolerr1', '   Insolation Flux Upper Unc. [Earth flux]'])],
#        [list(['pl_insolerr2', '   Insolation Flux Lower Unc. [Earth flux]'])],
#        [list(['pl_insollim', '    Insolation Flux Limit Flag'])],
#        [list(['pl_massj', '       Planet Mass [Jupiter mass]'])],
#        [list(['pl_massjerr1', '   Planet Mass Upper Unc. [Jupiter mass]'])],
#        [list(['pl_massjerr2', '   Planet Mass Lower Unc. [Jupiter mass]'])],
#        [list(['pl_massjlim', '    Planet Mass Limit Flag'])],
#        [list(['pl_msinij', '      Planet M*sin(i) [Jupiter mass]'])],
#        [list(['pl_msinijerr1', '  Planet M*sin(i) Upper Unc. [Jupiter mass]'])],
#        [list(['pl_msinijerr2', '  Planet M*sin(i) Lower Unc. [Jupiter mass]'])],
#        [list(['pl_msinijlim', '   Planet M*sin(i) Limit Flag'])],
#        [list(['pl_masse', '       Planet Mass [Earth mass]'])],
#        [list(['pl_masseerr1', '   Planet Mass Upper Unc. [Earth mass]'])],
#        [list(['pl_masseerr2', '   Planet Mass Lower Unc. [Earth mass]'])],
#        [list(['pl_masselim', '    Planet Mass Limit Flag'])],
#        [list(['pl_msinie', '      Planet M*sin(i) [Earth mass]'])],
#        [list(['pl_msinieerr1', '  Planet M*sin(i) Upper Unc. [Earth mass]'])],
#        [list(['pl_msinieerr2', '  Planet M*sin(i) Lower Unc. [Earth mass]'])],
#        [list(['pl_msinielim', '   Planet M*sin(i) Limit Flag'])],
#        [list(['pl_bmasse', '      Planet Mass or M*sin(i) [Earth mass]'])],
#        [ list(['pl_bmasseerr1', '  Planet Mass or M*sin(i) Upper Unc. [Earth mass]'])],
#        [ list(['pl_bmasseerr2', '  Planet Mass or M*sin(i) Lower Unc. [Earth mass]'])],
#        [list(['pl_bmasselim', '   Planet Mass or M*sin(i) Limit Flag'])],
#        [list(['pl_rade', '        Planet Radius [Earth radii]'])],
#        [list(['pl_radeerr1', '    Planet Radius Upper Unc. [Earth radii]'])],
#        [list(['pl_radeerr2', '    Planet Radius Lower Unc. [Earth radii]'])],
#        [list(['pl_radelim', '     Planet Radius Limit Flag'])],
#        [list(['pl_rads', '        Planet Radius [Solar radii]'])],
#        [list(['pl_radserr1', '    Planet Radius Upper Unc. [Solar radii]'])],
#        [list(['pl_radserr2', '    Planet Radius Lower Unc. [Solar radii]'])],
#        [list(['pl_radslim', '     Planet Radius Limit Flag'])],
#        [list(['pl_trandep', '     Transit Depth [percent]'])],
#        [list(['pl_trandeperr1', ' Transit Depth Upper Unc. [percent]'])],
#        [list(['pl_trandeperr2', ' Transit Depth Lower Unc. [percent]'])],
#        [list(['pl_trandeplim', '  Transit Depth Limit Flag'])],
#        [list(['pl_trandur', '     Transit Duration [days]'])],
#        [list(['pl_trandurerr1', ' Transit Duration Upper Unc. [days]'])],
#        [list(['pl_trandurerr2', ' Transit Duration Lower Unc. [days]'])],
#        [list(['pl_trandurlim', '  Transit Duration Limit Flag'])],
#        [list(['pl_tranmid', '     Transit Midpoint [days]'])],
#        [list(['pl_tranmiderr1', ' Transit Midpoint Upper Unc. [days]'])],
#        [list(['pl_tranmiderr2', ' Transit Midpoint Lower Unc. [days]'])],
#        [list(['pl_tranmidlim', '  Transit Midpoint Limit Flag'])],
#        [list(['pl_tsystemref', '  Time System Reference'])],
#        [list(['pl_imppar', '      Impact Parameter'])],
#        [list(['pl_impparerr1', '  Impact Parameter Upper Unc.'])],
#        [list(['pl_impparerr2', '  Impact Parameter Lower Unc.'])],
#        [list(['pl_impparlim', '   Impact Parameter Limit Flag'])],
#        [list(['pl_occdep', '      Occultation Depth [percentage]'])],
#        [list(['pl_occdeperr1', '  Occultation Depth Upper Unc. [percentage]'])],
#        [list(['pl_occdeperr2', '  Occultation Depth Lower Unc. [percentage]'])],
#        [list(['pl_occdeplim', '   Occultation Depth Limit Flag'])],
#        [list(['pl_ratdor', '      Ratio of Distance to Stellar Radius'])],
#        [ list(['pl_ratdorerr1', '  Ratio of Distance to Stellar Radius Upper Unc.'])],
#        [ list(['pl_ratdorerr2', '  Ratio of Distance to Stellar Radius Lower Unc.'])],
#        [ list(['pl_ratdorlim', '   Ratio of Distance to Stellar Radius Limit Flag'])],
#        [list(['pl_ratror', '      Ratio of Planet to Stellar Radius'])],
#        [list(['pl_ratrorerr1', '  Ratio of Planet to Stellar Radius Upper Unc.'])],
#        [list(['pl_ratrorerr2', '  Ratio of Planet to Stellar Radius Lower Unc.'])],
#        [list(['pl_ratrorlim', '   Ratio of Planet to Stellar Radius Limit Flag'])],
#        [list(['pl_def_reflink', ' Default Reference'])],
#        [list(['pl_disc', '        Year of Discovery'])],
#        [list(['pl_disc_reflink', ' Discovery Reference'])],
#        [list(['pl_locale', '      Discovery Locale'])],
#        [list(['pl_facility', '    Discovery Facility'])],
#        [list(['pl_telescope', '   Discovery Telescope'])],
#        [list(['pl_instrument', '  Discovery Instrument'])],
#        [list(['pl_status', '      Status'])],
#        [list(['pl_mnum', '        Number of Moons in System'])],
#        [list(['pl_st_npar', '     Number of Stellar and Planet Parameters'])],
#        [list(['pl_st_nref', '     Number of Stellar and Planet References'])],
#        [list(['pl_pelink', '      Link to Exoplanet Encyclopaedia'])],
#        [list(['pl_edelink', '     Link to Exoplanet Data Explorer'])],
#        [list(['pl_publ_date', '   Publication Date'])],
#        [list(['hd_name', '        HD Name'])],
#        [list(['hip_name', '       HIP Name'])],
#        [list(['st_rah', '         RA [hrs]'])],
#        [list(['st_glon', '        Galactic Longitude [deg]'])],
#        [list(['st_glat', '        Galactic Latitude [deg]'])],
#        [list(['st_elon', '        Ecliptic Longitude [deg]'])],
#        [list(['st_elat', '        Ecliptic Latitude [deg]'])],
#        [list(['st_plx', '         Parallax [mas]'])],
#        [list(['st_plxerr1', '     Parallax Upper Unc. [mas]'])],
#        [list(['st_plxerr2', '     Parallax Lower Unc. [mas]'])],
#        [list(['st_plxlim', '      Parallax Limit Flag'])],
#        [list(['st_plxblend', '    Parallax Blend Flag'])],
#        [list(['gaia_plx', '       Gaia Parallax [mas]'])],
#        [list(['gaia_plxerr1', '   Gaia Parallax Upper Unc. [mas]'])],
#        [list(['gaia_plxerr2', '   Gaia Parallax Lower Unc. [mas]'])],
#        [list(['gaia_plxlim', '    Gaia Parallax Limit Flag'])],
#        [list(['gaia_dist', '      Gaia Distance [pc]'])],
#        [list(['gaia_disterr1', '  Gaia Distance Upper Unc. [pc]'])],
#        [list(['gaia_disterr2', '  Gaia Distance Lower Unc. [pc]'])],
#        [list(['gaia_distlim', '   Gaia Distance Limit Flag'])],
#        [list(['st_pmra', '        Proper Motion (RA) [mas/yr]'])],
#        [list(['st_pmraerr', '     Proper Motion (RA) Unc. [mas/yr]'])],
#        [list(['st_pmralim', '     Proper Motion (RA) Limit Flag'])],
#        [list(['st_pmdec', '       Proper Motion (Dec) [mas/yr]'])],
#        [list(['st_pmdecerr', '    Proper Motion (Dec) Unc. [mas/yr]'])],
#        [list(['st_pmdeclim', '    Proper Motion (Dec) Limit Flag'])],
#        [list(['st_pm', '          Total Proper Motion [mas/yr]'])],
#        [list(['st_pmerr', '       Total Proper Motion Unc. [mas/yr]'])],
#        [list(['st_pmlim', '       Total Proper Motion Limit Flag'])],
#        [list(['st_pmblend', '     Total Proper Motion Blend Flag'])],
#        [list(['gaia_pmra', '      Gaia Proper Motion (RA) [mas/yr]'])],
#        [list(['gaia_pmraerr', '   Gaia Proper Motion (RA) Unc. [mas/yr]'])],
#        [list(['gaia_pmralim', '   Gaia Proper Motion (RA) Limit Flag'])],
#        [list(['gaia_pmdec', '     Gaia Proper Motion (Dec) [mas/yr]'])],
#        [list(['gaia_pmdecerr', '  Gaia Proper Motion (Dec) Unc. [mas/yr]'])],
#        [list(['gaia_pmdeclim', '  Gaia Proper Motion (Dec) Limit Flag'])],
#        [list(['gaia_pm', '        Gaia Total Proper Motion [mas/yr]'])],
#        [list(['gaia_pmerr', '     Gaia Total Proper Motion Unc. [mas/yr]'])],
#        [list(['gaia_pmlim', '     Gaia Total Proper Motion Limit Flag'])],
#        [list(['st_radv', '        Radial Velocity [km/s]'])],
#        [list(['st_radverr1', '    Radial Velocity Upper Unc. [km/s]'])],
#        [list(['st_radverr2', '    Radial Velocity Lower Unc. [km/s]'])],
#        [list(['st_radvlim', '     Radial Velocity Limit Flag'])],
#        [list(['st_radvblend', '   Radial Velocity Blend Flag'])],
#        [list(['st_sp', '          Spectral Type'])],
#        [list(['st_spstr', '       Spectral Type'])],
#        [list(['st_sperr', '       Spectral Type Unc.'])],
#        [list(['st_splim', '       Spectral Type Limit Flag'])],
#        [list(['st_spblend', '     Spectral Type Blend Flag'])],
#        [list(['st_logg', '        Stellar Surface Gravity [log10(cm/s**2)]'])],
#        [ list(['st_loggerr1', '    Stellar Surface Gravity Upper Unc. [log10(cm/s**2)]'])],
#        [ list(['st_loggerr2', '    Stellar Surface Gravity Lower Unc. [log10(cm/s**2)]'])],
#        [list(['st_logglim', '     Stellar Surface Gravity Limit Flag'])],
#        [list(['st_loggblend', '   Stellar Surface Gravity Blend Flag'])],
#        [list(['st_lum', '         Stellar Luminosity [log(Solar)]'])],
#        [list(['st_lumerr1', '     Stellar Luminosity Upper Unc. [log(Solar)]'])],
#        [list(['st_lumerr2', '     Stellar Luminosity Lower Unc. [log(Solar)]'])],
#        [list(['st_lumlim', '      Stellar Luminosity Limit Flag'])],
#        [list(['st_lumblend', '    Stellar Luminosity Blend Flag'])],
#        [list(['st_dens', '        Stellar Density [g/cm**3]'])],
#        [list(['st_denserr1', '    Stellar Density Upper Unc. [g/cm**3]'])],
#        [list(['st_denserr2', '    Stellar Density Lower Unc. [g/cm**3]'])],
#        [list(['st_denslim', '     Stellar Density Limit Flag'])],
#        [list(['st_metfe', '       Stellar Metallicity [dex]'])],
#        [list(['st_metfeerr1', '   Stellar Metallicity Upper Unc. [dex]'])],
#        [list(['st_metfeerr2', '   Stellar Metallicity Lower Unc. [dex]'])],
#        [list(['st_metfelim', '    Stellar Metallicity Limit Flag'])],
#        [list(['st_metfeblend', '  Stellar Metallicity Blend Flag'])],
#        [list(['st_metratio', '    Metallicity Ratio'])],
#        [list(['st_age', '         Stellar Age [Gyr]'])],
#        [list(['st_ageerr1', '     Stellar Age Upper Unc. [Gyr]'])],
#        [list(['st_ageerr2', '     Stellar Age Lower Unc. [Gyr]'])],
#        [list(['st_agelim', '      Stellar Age Limit Flag'])],
#        [list(['st_vsini', '       Rot. Velocity V*sin(i) [km/s]'])],
#        [list(['st_vsinierr1', '   Rot. Velocity V*sin(i) Upper Unc. [km/s]'])],
#        [list(['st_vsinierr2', '   Rot. Velocity V*sin(i) Lower Unc. [km/s]'])],
#        [list(['st_vsinilim', '    Rot. Velocity V*sin(i) Limit Flag'])],
#        [list(['st_vsiniblend', '  Rot. Velocity V*sin(i) Blend Flag'])],
#        [list(['st_acts', '        Stellar Activity S-index'])],
#        [list(['st_actserr', '     Stellar Activity S-index Unc.'])],
#        [list(['st_actslim', '     Stellar Activity S-index Limit Flag'])],
#        [list(['st_actsblend', '   Stellar Activity S-index Blend Flag'])],
#        [list(['st_actr', "        Stellar Activity log(R'HK)"])],
#        [list(['st_actrerr', "     Stellar Activity log(R'HK) Unc."])],
#        [list(['st_actrlim', "     Stellar Activity log(R'HK) Limit Flag"])],
#        [list(['st_actrblend', "   Stellar Activity log(R'HK) Blend Flag"])],
#        [list(['st_actlx', '       X-ray Activity log(L<sub>x</sub>)'])],
#        [list(['st_actlxerr', '    X-ray Activity log(L<sub>x</sub>) Unc.'])],
#        [list(['st_actlxlim', '    X-ray Activity log(L<sub>x</sub>) Limit Flag'])],
#        [list(['st_actlxblend', '  X-ray Activity log(L<sub>x</sub>) Blend Flag'])],
#        [list(['swasp_id', '       SWASP Identifier'])],
#        [list(['st_nts', '         Number of Time Series'])],
#        [list(['st_nplc', '        Number of Planet Transit Light Curves'])],
#        [list(['st_nglc', '        Number of General Light Curves'])],
#        [list(['st_nrvc', '        Number of Radial Velocity Time Series'])],
#        [list(['st_naxa', '        Number of Amateur Light Curves'])],
#        [list(['st_nimg', '        Number of Images'])],
#        [list(['st_nspec', '       Number of Spectra'])],
#        [list(['st_uj', '          U-band (Johnson) [mag]'])],
#        [list(['st_ujerr', '       U-band (Johnson) Unc. [mag]'])],
#        [list(['st_ujlim', '       U-band (Johnson) Limit Flag'])],
#        [list(['st_ujblend', '     U-band (Johnson) Blend Flag'])],
#        [list(['st_vj', '          V-band (Johnson) [mag]'])],
#        [list(['st_vjerr', '       V-band (Johnson) Unc. [mag]'])],
#        [list(['st_vjlim', '       V-band (Johnson) Limit Flag'])],
#        [list(['st_vjblend', '     V-band (Johnson) Blend Flag'])],
#        [list(['st_bj', '          B-band (Johnson) [mag]'])],
#        [list(['st_bjerr', '       B-band (Johnson) Unc. [mag]'])],
#        [list(['st_bjlim', '       B-band (Johnson) Limit Flag'])],
#        [list(['st_bjblend', '     B-band (Johnson) Blend Flag'])],
#        [list(['st_rc', '          R-band (Cousins) [mag]'])],
#        [list(['st_rcerr', '       R-band (Cousins) Unc. [mag]'])],
#        [list(['st_rclim', '       R-band (Cousins) Limit Flag'])],
#        [list(['st_rcblend', '     R-band (Cousins) Blend Flag'])],
#        [list(['st_ic', '          I-band (Cousins) [mag]'])],
#        [list(['st_icerr', '       I-band (Cousins) Unc. [mag]'])],
#        [list(['st_iclim', '       I-band (Cousins) Limit Flag'])],
#        [list(['st_icblend', '     I-band (Cousins) Blend Flag'])],
#        [list(['st_j', '           J-band (2MASS) [mag]'])],
#        [list(['st_jerr', '        J-band (2MASS) Unc. [mag]'])],
#        [list(['st_jlim', '        J-band (2MASS) Limit Flag'])],
#        [list(['st_jblend', '      J-band (2MASS) Blend Flag'])],
#        [list(['st_h', '           H-band (2MASS) [mag]'])],
#        [list(['st_herr', '        H-band (2MASS) Unc. [mag]'])],
#        [list(['st_hlim', '        H-band (2MASS) Limit Flag'])],
#        [list(['st_hblend', '      H-band (2MASS) Blend Flag'])],
#        [list(['st_k', '           Ks-band (2MASS) [mag]'])],
#        [list(['st_kerr', '        Ks-band (2MASS) Unc. [mag]'])],
#        [list(['st_klim', '        Ks-band (2MASS) Limit Flag'])],
#        [list(['st_kblend', '      Ks-band (2MASS) Blend Flag'])],
#        [list(['st_wise1', '       WISE 3.4um [mag]'])],
#        [list(['st_wise1err', '    WISE 3.4um Unc. [mag]'])],
#        [list(['st_wise1lim', '    WISE 3.4um Limit Flag'])],
#        [list(['st_wise1blend', '  WISE 3.4um Blend Flag'])],
#        [list(['st_wise2', '       WISE 4.6um [mag]'])],
#        [list(['st_wise2err', '    WISE 4.6um Unc. [mag]'])],
#        [list(['st_wise2lim', '    WISE 4.6um Limit Flag'])],
#        [list(['st_wise2blend', '  WISE 4.6um Blend Flag'])],
#        [list(['st_wise3', '       WISE 12.um [mag]'])],
#        [list(['st_wise3err', '    WISE 12.um Unc. [mag]'])],
#        [list(['st_wise3lim', '    WISE 12.um Limit Flag'])],
#        [list(['st_wise3blend', '  WISE 12.um Blend Flag'])],
#        [list(['st_wise4', '       WISE 22.um [mag]'])],
#        [list(['st_wise4err', '    WISE 22.um Unc. [mag]'])],
#        [list(['st_wise4lim', '    WISE 22.um Limit Flag'])],
#        [list(['st_wise4blend', '  WISE 22.um Blend Flag'])],
#        [list(['st_irac1', '       IRAC 3.6um [mag]'])],
#        [list(['st_irac1err', '    IRAC 3.6um Unc. [mag]'])],
#        [list(['st_irac1lim', '    IRAC 3.6um Limit Flag'])],
#        [list(['st_irac1blend', '  IRAC 3.6um Blend Flag'])],
#        [list(['st_irac2', '       IRAC 4.5um [mag]'])],
#        [list(['st_irac2err', '    IRAC 4.5um Unc. [mag]'])],
#        [list(['st_irac2lim', '    IRAC 4.5um Limit Flag'])],
#        [list(['st_irac2blend', '  IRAC 4.5um Blend Flag'])],
#        [list(['st_irac3', '       IRAC 5.8um [mag]'])],
#        [list(['st_irac3err', '    IRAC 5.8um Unc. [mag]'])],
#        [list(['st_irac3lim', '    IRAC 5.8um Limit Flag'])],
#        [list(['st_irac3blend', '  IRAC 5.8um Blend Flag'])],
#        [list(['st_irac4', '       IRAC 8.0um [mag]'])],
#        [list(['st_irac4err', '    IRAC 8.0um Unc. [mag]'])],
#        [list(['st_irac4lim', '    IRAC 8.0um Limit Flag'])],
#        [list(['st_irac4blend', '  IRAC 8.0um Blend Flag'])],
#        [list(['st_mips1', '       MIPS 24um [mag]'])],
#        [list(['st_mips1err', '    MIPS 24um Unc. [mag]'])],
#        [list(['st_mips1lim', '    MIPS 24um Limit Flag'])],
#        [list(['st_mips1blend', '  MIPS 24um Blend Flag'])],
#        [list(['st_mips2', '       MIPS 70um [mag]'])],
#        [list(['st_mips2err', '    MIPS 70um Unc. [mag]'])],
#        [list(['st_mips2lim', '    MIPS 70um Limit Flag'])],
#        [list(['st_mips2blend', '  MIPS 70um Blend Flag'])],
#        [list(['st_mips3', '       MIPS 160um [mag]'])],
#        [list(['st_mips3err', '    MIPS 160um Unc. [mag]'])],
#        [list(['st_mips3lim', '    MIPS 160um Limit Flag'])],
#        [list(['st_mips3blend', '  MIPS 160um Blend Flag'])],
#        [list(['st_iras1', '       IRAS 12um Flux [Jy]'])],
#        [list(['st_iras1err', '    IRAS 12um Flux Unc. [Jy]'])],
#        [list(['st_iras1lim', '    IRAS 12um Flux Limit Flag'])],
#        [list(['st_iras1blend', '  IRAS 12um Flux Blend Flag'])],
#        [list(['st_iras2', '       IRAS 25um Flux [Jy]'])],
#        [list(['st_iras2err', '    IRAS 25um Flux Unc. [Jy]'])],
#        [list(['st_iras2lim', '    IRAS 25um Flux Limit Flag'])],
#        [list(['st_iras2blend', '  IRAS 25um Flux Blend Flag'])],
#        [list(['st_iras3', '       IRAS 60um Flux [Jy]'])],
#        [list(['st_iras3err', '    IRAS 60um Flux Unc. [Jy]'])],
#        [list(['st_iras3lim', '    IRAS 60um Flux Limit Flag'])],
#        [list(['st_iras3blend', '  IRAS 60um Flux Blend Flag'])],
#        [list(['st_iras4', '       IRAS 100um Flux [Jy]'])],
#        [list(['st_iras4err', '    IRAS 100um Flux Unc. [Jy]'])],
#        [list(['st_iras4lim', '    IRAS 100um Flux Limit Flag'])],
#        [list(['st_iras4blend', '  IRAS 100um Flux Blend Flag'])],
#        [list(['st_photn', '       Number of Photometry Measurements'])],
#        [list(['st_umbj', '        U-B (Johnson) [mag]'])],
#        [list(['st_umbjerr', '     U-B (Johnson) Unc. [mag]'])],
#        [list(['st_umbjlim', '     U-B (Johnson) Limit Flag'])],
#        [list(['st_umbjblend', '   U-B (Johnson) Blend Flag'])],
#        [list(['st_bmvj', '        B-V (Johnson) [mag]'])],
#        [list(['st_bmvjerr', '     B-V (Johnson) Unc. [mag]'])],
#        [list(['st_bmvjlim', '     B-V (Johnson) Limit Flag'])],
#        [list(['st_bmvjblend', '   B-V (Johnson) Blend Flag'])],
#        [list(['st_vjmic', '       V-I (Johnson-Cousins) [mag]'])],
#        [list(['st_vjmicerr', '    V-I (Johnson-Cousins) Unc. [mag]'])],
#        [list(['st_vjmiclim', '    V-I (Johnson-Cousins) Limit Flag'])],
#        [list(['st_vjmicblend', '  V-I (Johnson-Cousins) Blend Flag'])],
#        [list(['st_vjmrc', '       V-R (Johnson-Cousins) [mag]'])],
#        [list(['st_vjmrcerr', '    V-R (Johnson-Cousins) Unc. [mag]'])],
#        [list(['st_vjmrclim', '    V-R (Johnson-Cousins) Limit Flag'])],
#        [list(['st_vjmrcblend', '  V-R (Johnson-Cousins) Blend Flag'])],
#        [list(['st_jmh2', '        J-H (2MASS) [mag]'])],
#        [list(['st_jmh2err', '     J-H (2MASS) Unc. [mag]'])],
#        [list(['st_jmh2lim', '     J-H (2MASS) Limit Flag'])],
#        [list(['st_jmh2blend', '   J-H (2MASS) Blend Flag'])],
#        [list(['st_hmk2', '        H-Ks (2MASS) [mag]'])],
#        [list(['st_hmk2err', '     H-Ks (2MASS) Unc. [mag]'])],
#        [list(['st_hmk2lim', '     H-Ks (2MASS) Limit Flag'])],
#        [list(['st_hmk2blend', '   H-Ks (2MASS) Blend Flag'])],
#        [list(['st_jmk2', '        J-Ks (2MASS) [mag]'])],
#        [list(['st_jmk2err', '     J-Ks (2MASS) Unc. [mag]'])],
#        [list(['st_jmk2lim', '     J-Ks (2MASS) Limit Flag'])],
#        [list(['st_jmk2blend', '   J-Ks (2MASS) Blend Flag'])],
#        [list(['st_bmy', '         b-y (Stromgren) [mag]'])],
#        [list(['st_bmyerr', '      b-y (Stromgren) Unc. [mag]'])],
#        [list(['st_bmylim', '      b-y (Stromgren) Limit Flag'])],
#        [list(['st_bmyblend', '    b-y (Stromgren) Blend Flag'])],
#        [list(['st_m1', '          m1 (Stromgren) [mag]'])],
#        [list(['st_m1err', '       m1 (Stromgren) Unc. [mag]'])],
#        [list(['st_m1lim', '       m1 (Stromgren) Limit Flag'])],
#        [list(['st_m1blend', '     m1 (Stromgren) Blend Flag'])],
#        [list(['st_c1', '          c1 (Stromgren) [mag]'])],
#        [list(['st_c1err', '       c1 (Stromgren) Unc. [mag]'])],
#        [list(['st_c1lim', '       c1 (Stromgren) Limit Flag'])],
#        [list(['st_c1blend', '     c1 (Stromgren) Blend Flag'])],
#        [list(['st_colorn', '      Number of Color Measurements'])]], dtype=object)

# %%
# We should remove null values for range of masses for the second analysis of Earth similarity. 
# We should NOT remove null values for range of masses for the first analysis of planet visualization.

# %% [markdown]
# ## First Analysis: Planet Visualization Based on Host Star Distance and Relative Radius

# %%
df_planet_radius_estimate = df_planets_clean[df_planets_clean["Planet Radius [Earth radii]"].notnull()][["Planet Radius [Earth radii]"]]
# df_planet_radius_estimate

# %%
df_planet_star_distance_estimate = df_planets_clean[df_planets_clean["Ratio of Distance to Stellar Radius"].notnull()][["Ratio of Distance to Stellar Radius"]]
# df_planet_star_distance_estimate

# %%
dataset1 = pd.concat([df_planet_radius_estimate, df_planet_star_distance_estimate], axis=1, join='inner')
dataset1['Data Point Size'] = round(1000 * (dataset1['Planet Radius [Earth radii]'] / dataset1['Planet Radius [Earth radii]'].max()), 2)
dataset1.describe()
# Out:
#        Planet Radius [Earth radii]  Ratio of Distance to Stellar Radius  \
# count                   477.000000                           477.000000
# mean                      8.563585                            29.353578
# std                       6.155047                            54.496961
# min                       0.403000                             2.496000
# 25%                       2.330000                             7.360000
# 50%                       9.120000                            12.170000
# 75%                      13.900000                            25.800000
# max                      23.371000                           576.700000
#
#        Data Point Size
# count       477.000000
# mean        366.419287
# std         263.362483
# min          17.240000
# 25%          99.700000
# 50%         390.230000
# 75%         594.750000
# max        1000.000000

# %%
# Display scatter plot (X: Planet Radius, Y: Distance to Star)
X = dataset1['Planet Radius [Earth radii]']
Y = dataset1['Ratio of Distance to Stellar Radius']
Z = dataset1['Data Point Size']

plt.title('COMPARISON OF EXOPLANET RADII TO RESPECTIVE DISTANCES TO HOST STARS\n')
plt.xlabel('\nPlanet Radius [Earth radii]')
plt.ylabel('Planet Distance to Host Star [Earth-to-Sun Lengths]\n')

fitness = np.polyfit(X, Y, deg=1)
m = fitness[0]
b = fitness[1]
Y_hat = (m * X) + b
print(np.var(Y_hat))
Y_hat_label = 'Y = {}X + {}.'.format(round(m, 2), round(b, 2))
# print('\n\nRegression line of best fit is: Y =', round(m, 2), 'X +', round(b, 2), '\n\n')
plt.plot(X, Y_hat, color='red', label='\nLinear Regression Line of Best Fit: \n\n{}'.format(Y_hat_label))
plt.scatter(X, Y, s=Z, label=None, c=-np.log10(Y), cmap='viridis')
plt.colorbar(label='\nlog$_{10}$(Planet-to-Star Distance)')
plt.clim(-2.75, 0.25)
plt.legend(frameon=False, loc='upper right')

# Get figure size and set height to 12 and width to 20
fig_size = plt.rcParams['figure.figsize']
fig_size
fig_size[0] = 20    # width
fig_size[1] = 12    # height
plt.rcParams['figure.figsize'] = fig_size
# Out:
# 203.6763487604552

# %%
# Grab samples from dataset.
def get_sample(data, n=30):
    """Grabs a random subsample of size 'n' from dataset.
    Outputs the mean of the subsample."""
    sample = np.random.choice(data, size=n)
    return np.mean(sample)

def create_sample_distribution(dataset, size=100, n=30):
    """Creates a dataset of subsample means.  The length of the dataset is specified by the 'size' 
    keyword argument. Should return the entire sample distribution as a numpy array.  """
    sample_averages = np.array([])
    for i in range(0, size):
        average = get_sample(dataset, n)
        sample_averages = np.append(sample_averages, average)   
    return sample_averages

# %% [markdown]
# # Define null and alternative hypotheses for planetary radius distribution analysis.
#
# - Ho:    Most planets (=<50%) are not bigger than Earth.
# - Ha:    Most planets (>50%) are bigger than Earth.

# %%
# Get filtered dataset
q1 = df_planet_radius_estimate.describe().iloc[4, 0]
q3 = df_planet_radius_estimate.describe().iloc[6, 0]
iqr = q3 - q1
f = iqr * 1.5
lower_fence = round(q1 - f, 2)
upper_fence = round(q3 + f, 2)

df_planet_radii_filtered = df_planet_radius_estimate[(df_planet_radius_estimate['Planet Radius [Earth radii]'] >= lower_fence) & (df_planet_radius_estimate['Planet Radius [Earth radii]'] <= upper_fence)]
df_planet_radii_filtered.describe()
data_rads = df_planet_radii_filtered['Planet Radius [Earth radii]']

# %%
# Set sample distribution size to be 30% of the population size
radii_sample_dist = create_sample_distribution(data_rads, int(0.3*len(df_planet_radii_filtered)), 50)

# %%
plt.hist(radii_sample_dist)
plt.plot(0 * Y + 1, Y, c='r')
plt.ylim(0,200)
# Out:
# (0, 200)

# %% [markdown]
# # Define null and alternative hypotheses for planet-to-star-distance distribution analysis.
#
# - Ho:    Most planets (=<50%) are not further from their host stars as the Earth is to the Sun.
# - Ha:    Most planets (>50%) are further from their host stars as the Earth is to the Sun.

# %%
# Get filtered dataset
q1 = df_planet_star_distance_estimate.describe().iloc[4, 0]
q3 = df_planet_star_distance_estimate.describe().iloc[6, 0]
iqr = q3 - q1
f = iqr * 1.5
lower_fence = round(q1 - f, 2)
upper_fence = round(q3 + f, 2)

df_planet_star_dists_filtered = df_planet_star_distance_estimate[(df_planet_star_distance_estimate['Ratio of Distance to Stellar Radius'] >= lower_fence) & (df_planet_star_distance_estimate['Ratio of Distance to Stellar Radius'] <= upper_fence)]
df_planet_star_dists_filtered.describe()
data_stars = df_planet_star_dists_filtered['Ratio of Distance to Stellar Radius']

# %%
# Set sample distribution size to be 30% of the population size
stars_sample_dist = create_sample_distribution(data_stars, int(0.3*len(df_planet_star_dists_filtered)), 50)

# %%
plt.hist(stars_sample_dist)
plt.plot(0 * Y + 1, Y, c='r')
plt.ylim(0,35)
# Out:
# (0, 35)

# %%
plt.hist(X, 24)
plt.title('HISTGRAM OF EXOPLANET RADII TO RESPECTIVE HOST STARS RADII\n')
plt.xlabel('\nPlanet Radius [Earth radii]')
plt.ylabel('Frequency\n')
# Out:
# Text(0,0.5,'Frequency\n')

# %%
plt.hist(Y, 50)
plt.title('HISTGRAM OF RATIO OF EXOPLANET DISTANCE TO HOST STARS\n')
plt.xlabel('\nRatio of Distance to Stellar Radius')
plt.ylabel('Frequency\n')
# Out:
# Text(0,0.5,'Frequency\n')

# %% [markdown]
# ## Second Analysis: Relationship between host star radius and planets radius

# %%
df_Stellar_Radius = df_planets_clean[df_planets_clean['Stellar Radius [Solar radii]'].notnull()][['Stellar Radius [Solar radii]', 'Host Name']]

# %%
dataset2 = pd.concat([df_planet_radius_estimate, df_Stellar_Radius], axis=1, join='inner')
dataset2['Data Point Size'] = round(1000 * (dataset2['Planet Radius [Earth radii]'] / dataset2['Planet Radius [Earth radii]'].max()), 2)
dataset2.describe()
# Out:
#        Planet Radius [Earth radii]  Stellar Radius [Solar radii]  \
# count                  2808.000000                   2808.000000
# mean                      3.978175                      1.023743
# std                       4.343391                      0.405042
# min                       0.320000                      0.090000
# 25%                       1.550000                      0.800000
# 50%                       2.300000                      0.950000
# 75%                       3.400000                      1.180000
# max                      23.430000                      6.300000
#
#        Data Point Size
# count      2808.000000
# mean        169.789829
# std         185.377412
# min          13.660000
# 25%          66.150000
# 50%          98.160000
# 75%         145.110000
# max        1000.000000

# %%
# Display scatter plot (X: Planet Radius, Y: Distance to Star)
X = dataset2['Planet Radius [Earth radii]']
Y = dataset2['Stellar Radius [Solar radii]']
Z = dataset2['Data Point Size']

plt.title('COMPARISON OF EXOPLANET RADII TO RESPECTIVE HOST STARS RADII\n')
plt.xlabel('\nPlanet Radius [Earth radii]')
plt.ylabel('Host Star Radius [Solar radii]\n')

fitness = np.polyfit(X, Y, deg=1)
m = fitness[0]
b = fitness[1]
Y_hat = (m * X) + b
print(np.var(Y_hat))
Y_hat_label = 'Y = {}X + {}.'.format(round(m, 2), round(b, 2))
# print('\n\nRegression line of best fit is: Y =', round(m, 2), 'X +', round(b, 2), '\n\n')
plt.plot(X, Y_hat, color='red', label='\nLinear Regression Line of Best Fit: \n\n{}'.format(Y_hat_label))
plt.scatter(X, Y, s=Z, label=None, c=-np.log10(Y), cmap='viridis')
plt.colorbar(label='\nlog$_{10}$(Host Star Radius [Solar radii])')
plt.clim(-1.0, 0.5)
plt.legend(frameon=False, loc='upper right')

# Get figure size and set height to 12 and width to 20
fig_size = plt.rcParams['figure.figsize']
fig_size
fig_size[0] = 20    # width
fig_size[1] = 12    # height
plt.rcParams['figure.figsize'] = fig_size
# Out:
# 0.019970297688079685

# %%
plt.hist(X, 24)
plt.title('HISTGRAM OF EXOPLANET RADII TO RESPECTIVE HOST STARS RADII\n')
plt.xlabel('\nPlanet Radius [Earth radii]')
plt.ylabel('Frequency\n')
# Out:
# Text(0,0.5,'Frequency\n')

# %%
df_Stellar_Radius_clean = df_Stellar_Radius.groupby(['Host Name']).first().reset_index()

# %%
plt.hist(df_Stellar_Radius_clean['Stellar Radius [Solar radii]'], 50)
plt.title('HISTGRAM OF HOST STARS RADII\n')
plt.xlabel('\nStellar Radius [Solar radii]')
plt.ylabel('Frequency\n')
# Out:
# Text(0,0.5,'Frequency\n')

# %% [markdown]
# ## Third Analysis: Planet Mapping Based on Similarity to Earth

# %%
df_planet_masses_ranged = df_planets_clean[["Planet Mass or M*sin(i) [Earth mass]", "Planet Mass or M*sin(i) Upper Unc. [Earth mass]", "Planet Mass or M*sin(i) Lower Unc. [Earth mass]"]]
# df_planet_masses_simple = df_planets_clean[["Planet Mass or M*sin(i) [Earth mass]"]]
df_planet_masses_ranged_cleaned = df_planet_masses_ranged[df_planet_masses_ranged["Planet Mass or M*sin(i) Lower Unc. [Earth mass]"].notnull()]
df_planet_masses_simple_cleaned = df_planet_masses_ranged_cleaned[["Planet Mass or M*sin(i) [Earth mass]"]]

# df_planet_masses_ranged_cleaned    # We need this to visualize planets with 
# df_planet_masses_simple_cleaned    # We need this to find planets like Earth (second analysis)

# %%
# join mass data
df_Radius_Disrance = dataset1.drop("Data Point Size", 1)
df_M_R_D = pd.concat([df_planet_Radius_Disrance, df_planet_masses_simple_cleaned], axis=1, join='inner')

# %%
# clean data of temperature of the star
df_star_temp = df_planets_clean[["Effective Temperature [K]", "Host Name"]]
df_star_temp_clean = df_star_temp[df_star_temp['Effective Temperature [K]'].notnull()]
df_star_temp_clean = df_star_temp_clean.rename(columns = {"Effective Temperature [K]": "Temperature of the star [K]"})

# %%
# join temperature of the star *the temperature of the sun is 5778 [K]
df_M_R_D_ST = pd.concat([df_M_R_D, df_star_temp_clean], axis=1, join='inner')
df_M_R_D_ST.describe()
# Out:
#        Planet Radius [Earth radii]  Ratio of Distance to Stellar Radius  \
# count                   297.000000                           297.000000
# mean                     11.671859                            15.196691
# std                       5.145316                            18.377043
# min                       0.772000                             2.496000
# 25%                       9.640000                             6.280000
# 50%                      12.733000                             8.870000
# 75%                      14.986000                            15.152000
# max                      23.371000                           124.700000
#
#        Planet Mass or M*sin(i) [Earth mass]  Temperature of the star [K]
# count                            297.000000                   297.000000
# mean                             409.591848                  5670.060606
# std                              711.838158                   787.886158
# min                                0.410000                  2559.000000
# 25%                               85.810000                  5380.000000
# 50%                              242.176000                  5754.000000
# 75%                              435.410000                  6090.000000
# max                             6883.910000                 10170.000000

# %%
df_like_earth = df_M_R_D_ST[(df_M_R_D_ST['Planet Mass or M*sin(i) [Earth mass]']<2) & (df_M_R_D_ST['Planet Radius [Earth radii]']<2)]
df_like_earth
# Out:
#       Planet Radius [Earth radii]  Ratio of Distance to Stellar Radius  \
# 1108                        1.800                                18.55
# 3379                        1.086                                20.50
# 3380                        1.056                                28.08
# 3381                        0.772                                39.55
# 3382                        0.918                                51.97
# 3383                        1.045                                68.40
# 3384                        1.127                                83.20
#
#       Planet Mass or M*sin(i) [Earth mass]  Temperature of the star [K]
# 1108                                  1.90                       5663.0
# 3379                                  0.85                       2559.0
# 3380                                  1.38                       2559.0
# 3381                                  0.41                       2559.0
# 3382                                  0.62                       2559.0
# 3383                                  0.68                       2559.0
# 3384                                  1.34                       2559.0

# %% [markdown]
# # TODO
#
# ## First Analysis:
# - <del>Find and clean separate dataframes for Star Distance and Planet Radius
# - Align and join dataframes for Star Distance and Planet Radius
# - Filter outliers using 1.5x method
# - Visualization via Scatterplot (As they increase in Planet Radius value, they increase in visual size)
# - [STRETCH] Find approximate line of regression (MatPlotLib and SciPy)
#
# ## Second Analysis:
# - Create list of label vectors for Earth similarity
# - Find, clean, align, and join dataframes for all planets having values for similarity vectors
# - Filter outliers using 1.5x method
# - Sample X amount of planets from joined data population
# - Check for similarity to Earth (does the value ranges cross or fall within ranges)
# - [SUPER STRETCH] Use kNN to approximate similarity between
